# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import time
from datetime import datetime

# %%
# Import additional dependencies
from citipy import citipy

import requests

# Import linregress
from scipy.stats import linregress

# Import gmaps
import gmaps

# %%
# Import the OpenWeather API key from config.py
from config import weather_api_key

# Import the Google Maps API key from config.py
from config import g_key

# %%
# starting URL for weathermap API call (from OpenWeather documentation)
url = "http://api.openweathermap.org/data/2.5/weather?" + "appid=" + weather_api_key + "&units=Imperial"

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs) # zip() packs lats and lngs in pairs
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs) # unzips lat_lngs

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination using .nearest_city() and .city_name
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 742

# %%
# Create an empty list to hold the weather data.
weatherpy_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into weatherpy_data list.
        weatherpy_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | salalah
# Processing Record 2 of Set 1 | thompson
# Processing Record 3 of Set 1 | astoria
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | klaksvik
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | severo-kurilsk
# Processing Record 13 of Set 1 | chumikan
# Processing Record 14 of Set 1 | kodiak
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 1 | kapaa
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | banikoara
# Processing Record 20 of Set 1 | tasiilaq
# Processing Record 21 of Set 1 | tancanhuitz
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 1 | narsaq
# Processing Record 26 of Set 1 | pevek
# Processing Record 27 of Set 1 | upernavik
# Processing Record 28 of Set 1 | port blair
# Processing Record 29 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 1 | hearst
# Processing Record 31 of Set 1 | georgetown
# Processing Record 32 of Set 1 | kaitangata
# Processing Record 33 of Set 1 | kudahuvadhoo
# Processing Record 34 of Set 1 | ilulissat
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | dospat
# Processing Record 37 of Set 1 | itupiranga
# Processing Record 38 of Set 1 | avarua
# Processing Record 39 of Set 1 | topola
# Processing Record 40 of Set 1 | jalu
# Processing Record 41 of Set 1 | quatre cocos
# Processing Record 42 of Set 1 | kahului
# Processing Record 43 of Set 1 | raudeberg
# Processing Record 44 of Set 1 | chokurdakh
# Processing Record 45 of Set 1 | bima
# Processing Record 46 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 1 | dikson
# Processing Record 50 of Set 1 | silver city
# Processing Record 1 of Set 2 | tallahassee
# Processing Record 2 of Set 2 | hithadhoo
# Processing Record 3 of Set 2 | luganville
# Processing Record 4 of Set 2 | henties bay
# Processing Record 5 of Set 2 | skorping
# Processing Record 6 of Set 2 | galveston
# Processing Record 7 of Set 2 | itacurubi del rosario
# Processing Record 8 of Set 2 | carnarvon
# Processing Record 9 of Set 2 | sukhumi
# Processing Record 10 of Set 2 | mahebourg
# Processing Record 11 of Set 2 | butaritari
# Processing Record 12 of Set 2 | coroico
# Processing Record 13 of Set 2 | tiksi
# Processing Record 14 of Set 2 | bathsheba
# Processing Record 15 of Set 2 | torbay
# Processing Record 16 of Set 2 | jieshi
# Processing Record 17 of Set 2 | hermanus
# Processing Record 18 of Set 2 | aykhal
# Processing Record 19 of Set 2 | nadym
# Processing Record 20 of Set 2 | cherskiy
# Processing Record 21 of Set 2 | port alfred
# Processing Record 22 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 2 | brae
# Processing Record 24 of Set 2 | oranjemund
# Processing Record 25 of Set 2 | luderitz
# Processing Record 26 of Set 2 | port hedland
# Processing Record 27 of Set 2 | yanan
# City not found. Skipping...
# Processing Record 28 of Set 2 | bethel
# Processing Record 29 of Set 2 | sistranda
# Processing Record 30 of Set 2 | saskylakh
# Processing Record 31 of Set 2 | schruns
# Processing Record 32 of Set 2 | victoria
# Processing Record 33 of Set 2 | saint-philippe
# Processing Record 34 of Set 2 | santa fe
# Processing Record 35 of Set 2 | karratha
# Processing Record 36 of Set 2 | wakema
# Processing Record 37 of Set 2 | bilibino
# Processing Record 38 of Set 2 | tevaitoa
# Processing Record 39 of Set 2 | kruisfontein
# Processing Record 40 of Set 2 | cape town
# Processing Record 41 of Set 2 | touros
# Processing Record 42 of Set 2 | san patricio
# Processing Record 43 of Set 2 | kismayo
# Processing Record 44 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 2 | clyde river
# Processing Record 46 of Set 2 | khuzdar
# Processing Record 47 of Set 2 | east london
# Processing Record 48 of Set 2 | mandalgovi
# Processing Record 49 of Set 2 | malmesbury
# Processing Record 50 of Set 2 | norman wells
# Processing Record 1 of Set 3 | atuona
# Processing Record 2 of Set 3 | castro
# Processing Record 3 of Set 3 | suntar
# Processing Record 4 of Set 3 | mount gambier
# Processing Record 5 of Set 3 | ribeira grande
# Processing Record 6 of Set 3 | qaanaaq
# Processing Record 7 of Set 3 | grand gaube
# Processing Record 8 of Set 3 | kibara
# Processing Record 9 of Set 3 | bahia blanca
# Processing Record 10 of Set 3 | cidreira
# Processing Record 11 of Set 3 | leningradskiy
# Processing Record 12 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 13 of Set 3 | cayenne
# Processing Record 14 of Set 3 | sarakhs
# Processing Record 15 of Set 3 | bubaque
# Processing Record 16 of Set 3 | airai
# Processing Record 17 of Set 3 | ostrovnoy
# Processing Record 18 of Set 3 | sao filipe
# Processing Record 19 of Set 3 | yar-sale
# Processing Record 20 of Set 3 | nuuk
# Processing Record 21 of Set 3 | katsuura
# Processing Record 22 of Set 3 | popondetta
# Processing Record 23 of Set 3 | opuwo
# Processing Record 24 of Set 3 | taburi
# City not found. Skipping...
# Processing Record 25 of Set 3 | castrovillari
# Processing Record 26 of Set 3 | kloulklubed
# Processing Record 27 of Set 3 | barrow
# Processing Record 28 of Set 3 | hanchuan
# Processing Record 29 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 3 | menongue
# Processing Record 32 of Set 3 | vila velha
# Processing Record 33 of Set 3 | sinnamary
# Processing Record 34 of Set 3 | mabaruma
# Processing Record 35 of Set 3 | candawaga
# City not found. Skipping...
# Processing Record 36 of Set 3 | aquiraz
# Processing Record 37 of Set 3 | nikolskoye
# Processing Record 38 of Set 3 | tabory
# Processing Record 39 of Set 3 | weatherford
# Processing Record 40 of Set 3 | bud
# Processing Record 41 of Set 3 | soe
# Processing Record 42 of Set 3 | erzin
# Processing Record 43 of Set 3 | ponta do sol
# Processing Record 44 of Set 3 | kilindoni
# Processing Record 45 of Set 3 | adolfo lopez mateos
# Processing Record 46 of Set 3 | dawlatabad
# Processing Record 47 of Set 3 | lufilufi
# Processing Record 48 of Set 3 | abay
# Processing Record 49 of Set 3 | cumaribo
# City not found. Skipping...
# Processing Record 50 of Set 3 | chuy
# Processing Record 1 of Set 4 | sitka
# Processing Record 2 of Set 4 | tolaga bay
# Processing Record 3 of Set 4 | sitio novo do tocantins
# Processing Record 4 of Set 4 | praia da vitoria
# Processing Record 5 of Set 4 | treinta y tres
# Processing Record 6 of Set 4 | alice springs
# Processing Record 7 of Set 4 | puerto lempira
# Processing Record 8 of Set 4 | san cristobal
# Processing Record 9 of Set 4 | hilo
# Processing Record 10 of Set 4 | ancud
# Processing Record 11 of Set 4 | ketchikan
# Processing Record 12 of Set 4 | vestmannaeyjar
# Processing Record 13 of Set 4 | akdepe
# Processing Record 14 of Set 4 | ukiah
# Processing Record 15 of Set 4 | talnakh
# Processing Record 16 of Set 4 | fortuna
# Processing Record 17 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 4 | makakilo city
# Processing Record 19 of Set 4 | mar del plata
# Processing Record 20 of Set 4 | rawson
# Processing Record 21 of Set 4 | aksu
# Processing Record 22 of Set 4 | cabo san lucas
# Processing Record 23 of Set 4 | conde
# Processing Record 24 of Set 4 | arraial do cabo
# Processing Record 25 of Set 4 | evans
# Processing Record 26 of Set 4 | bonthe
# Processing Record 27 of Set 4 | orapa
# Processing Record 28 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 4 | pangkalanbuun
# Processing Record 30 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 4 | prince rupert
# Processing Record 32 of Set 4 | port pirie
# Processing Record 33 of Set 4 | saint george
# Processing Record 34 of Set 4 | jinchang
# Processing Record 35 of Set 4 | balkanabat
# Processing Record 36 of Set 4 | longyearbyen
# Processing Record 37 of Set 4 | bengkulu
# Processing Record 38 of Set 4 | charters towers
# Processing Record 39 of Set 4 | deputatskiy
# Processing Record 40 of Set 4 | alcudia
# Processing Record 41 of Set 4 | hofn
# Processing Record 42 of Set 4 | lebu
# Processing Record 43 of Set 4 | sisimiut
# Processing Record 44 of Set 4 | college
# Processing Record 45 of Set 4 | bajo baudo
# City not found. Skipping...
# Processing Record 46 of Set 4 | bulawayo
# Processing Record 47 of Set 4 | paka
# Processing Record 48 of Set 4 | axim
# Processing Record 49 of Set 4 | windham
# Processing Record 50 of Set 4 | sadovoye
# Processing Record 1 of Set 5 | matara
# Processing Record 2 of Set 5 | tuatapere
# Processing Record 3 of Set 5 | meulaboh
# Processing Record 4 of Set 5 | taoudenni
# Processing Record 5 of Set 5 | ondorhaan
# City not found. Skipping...
# Processing Record 6 of Set 5 | pierre
# Processing Record 7 of Set 5 | beringovskiy
# Processing Record 8 of Set 5 | la paz
# Processing Record 9 of Set 5 | lorengau
# Processing Record 10 of Set 5 | udachnyy
# Processing Record 11 of Set 5 | tuktoyaktuk
# Processing Record 12 of Set 5 | manggar
# Processing Record 13 of Set 5 | puerto carreno
# Processing Record 14 of Set 5 | ajaccio
# Processing Record 15 of Set 5 | sorland
# Processing Record 16 of Set 5 | dandong
# Processing Record 17 of Set 5 | amapa
# Processing Record 18 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 5 | forio
# Processing Record 20 of Set 5 | abu samrah
# Processing Record 21 of Set 5 | pontianak
# Processing Record 22 of Set 5 | jumla
# Processing Record 23 of Set 5 | mount isa
# Processing Record 24 of Set 5 | daxian
# City not found. Skipping...
# Processing Record 25 of Set 5 | port elizabeth
# Processing Record 26 of Set 5 | kavieng
# Processing Record 27 of Set 5 | xuanhua
# Processing Record 28 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 5 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 30 of Set 5 | faanui
# Processing Record 31 of Set 5 | diapaga
# Processing Record 32 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 5 | roald
# Processing Record 34 of Set 5 | varzelandia
# Processing Record 35 of Set 5 | tomatlan
# Processing Record 36 of Set 5 | smalininkai
# Processing Record 37 of Set 5 | akyab
# Processing Record 38 of Set 5 | almenara
# Processing Record 39 of Set 5 | jamnah
# City not found. Skipping...
# Processing Record 40 of Set 5 | faya
# Processing Record 41 of Set 5 | poya
# Processing Record 42 of Set 5 | rorvik
# Processing Record 43 of Set 5 | provideniya
# Processing Record 44 of Set 5 | sampit
# Processing Record 45 of Set 5 | olinda
# Processing Record 46 of Set 5 | usinsk
# Processing Record 47 of Set 5 | micomeseng
# Processing Record 48 of Set 5 | marzuq
# Processing Record 49 of Set 5 | gorontalo
# Processing Record 50 of Set 5 | grasse
# Processing Record 1 of Set 6 | kangaatsiaq
# Processing Record 2 of Set 6 | souillac
# Processing Record 3 of Set 6 | new norfolk
# Processing Record 4 of Set 6 | pangnirtung
# Processing Record 5 of Set 6 | gopamau
# Processing Record 6 of Set 6 | shimoda
# Processing Record 7 of Set 6 | vinh
# Processing Record 8 of Set 6 | yazykovo
# Processing Record 9 of Set 6 | anadyr
# Processing Record 10 of Set 6 | bandar-e anzali
# Processing Record 11 of Set 6 | suharau
# Processing Record 12 of Set 6 | xingyi
# Processing Record 13 of Set 6 | rawah
# Processing Record 14 of Set 6 | oskarshamn
# Processing Record 15 of Set 6 | antalaha
# Processing Record 16 of Set 6 | sola
# Processing Record 17 of Set 6 | iqaluit
# Processing Record 18 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 6 | kavaratti
# Processing Record 20 of Set 6 | nabagram
# Processing Record 21 of Set 6 | codrington
# Processing Record 22 of Set 6 | preobrazheniye
# Processing Record 23 of Set 6 | hamilton
# Processing Record 24 of Set 6 | tual
# Processing Record 25 of Set 6 | mazatlan
# Processing Record 26 of Set 6 | dunhua
# Processing Record 27 of Set 6 | krasnousolskiy
# City not found. Skipping...
# Processing Record 28 of Set 6 | ucluelet
# Processing Record 29 of Set 6 | lasa
# Processing Record 30 of Set 6 | ponta delgada
# Processing Record 31 of Set 6 | monrovia
# Processing Record 32 of Set 6 | muros
# Processing Record 33 of Set 6 | broome
# Processing Record 34 of Set 6 | avera
# Processing Record 35 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 36 of Set 6 | calabozo
# Processing Record 37 of Set 6 | veraval
# Processing Record 38 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 6 | krasnogvardeyets
# Processing Record 40 of Set 6 | halifax
# Processing Record 41 of Set 6 | do rud
# City not found. Skipping...
# Processing Record 42 of Set 6 | kantang
# Processing Record 43 of Set 6 | eureka
# Processing Record 44 of Set 6 | bandarbeyla
# Processing Record 45 of Set 6 | kenai
# Processing Record 46 of Set 6 | verkh-suetka
# Processing Record 47 of Set 6 | laguna
# Processing Record 48 of Set 6 | russell
# Processing Record 49 of Set 6 | caravelas
# Processing Record 50 of Set 6 | anloga
# Processing Record 1 of Set 7 | tecpan
# Processing Record 2 of Set 7 | nizhnevartovsk
# Processing Record 3 of Set 7 | oshawa
# Processing Record 4 of Set 7 | rio grande
# Processing Record 5 of Set 7 | khandbari
# Processing Record 6 of Set 7 | khatanga
# Processing Record 7 of Set 7 | eyl
# Processing Record 8 of Set 7 | naze
# Processing Record 9 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 7 | saquarema
# Processing Record 11 of Set 7 | luzilandia
# Processing Record 12 of Set 7 | talas
# Processing Record 13 of Set 7 | zurrieq
# Processing Record 14 of Set 7 | sangueya
# Processing Record 15 of Set 7 | praia
# Processing Record 16 of Set 7 | mana
# Processing Record 17 of Set 7 | exaplatanos
# Processing Record 18 of Set 7 | brcko
# Processing Record 19 of Set 7 | correntina
# Processing Record 20 of Set 7 | jibuti
# Processing Record 21 of Set 7 | milingimbi
# City not found. Skipping...
# Processing Record 22 of Set 7 | hailar
# Processing Record 23 of Set 7 | nanortalik
# Processing Record 24 of Set 7 | birao
# Processing Record 25 of Set 7 | bacolod
# Processing Record 26 of Set 7 | dubovskoye
# Processing Record 27 of Set 7 | morales
# Processing Record 28 of Set 7 | bambous virieux
# Processing Record 29 of Set 7 | taltal
# Processing Record 30 of Set 7 | haines junction
# Processing Record 31 of Set 7 | berlevag
# Processing Record 32 of Set 7 | hun
# Processing Record 33 of Set 7 | great yarmouth
# Processing Record 34 of Set 7 | ahipara
# Processing Record 35 of Set 7 | alta floresta
# Processing Record 36 of Set 7 | san lazaro
# Processing Record 37 of Set 7 | salvador
# Processing Record 38 of Set 7 | lavrentiya
# Processing Record 39 of Set 7 | padang
# Processing Record 40 of Set 7 | sibiti
# Processing Record 41 of Set 7 | lata
# Processing Record 42 of Set 7 | quang ngai
# Processing Record 43 of Set 7 | farafangana
# Processing Record 44 of Set 7 | okha
# Processing Record 45 of Set 7 | mayna
# Processing Record 46 of Set 7 | camacari
# Processing Record 47 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 7 | luang prabang
# Processing Record 49 of Set 7 | barstow
# Processing Record 50 of Set 7 | houston
# Processing Record 1 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 2 of Set 8 | adrar
# Processing Record 3 of Set 8 | alexandria
# Processing Record 4 of Set 8 | peniche
# Processing Record 5 of Set 8 | cody
# Processing Record 6 of Set 8 | kaikalur
# Processing Record 7 of Set 8 | araouane
# Processing Record 8 of Set 8 | biak
# Processing Record 9 of Set 8 | nelson bay
# Processing Record 10 of Set 8 | homer
# Processing Record 11 of Set 8 | saldanha
# Processing Record 12 of Set 8 | kupang
# Processing Record 13 of Set 8 | kieta
# Processing Record 14 of Set 8 | kununurra
# Processing Record 15 of Set 8 | podosinovets
# Processing Record 16 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 8 | guerrero negro
# Processing Record 19 of Set 8 | watertown
# Processing Record 20 of Set 8 | daphne
# Processing Record 21 of Set 8 | santa vitoria do palmar
# Processing Record 22 of Set 8 | mpanda
# Processing Record 23 of Set 8 | muisne
# Processing Record 24 of Set 8 | huron
# Processing Record 25 of Set 8 | vardo
# Processing Record 26 of Set 8 | murray bridge
# Processing Record 27 of Set 8 | tessalit
# Processing Record 28 of Set 8 | ostrowiec swietokrzyski
# Processing Record 29 of Set 8 | verkhoyansk
# Processing Record 30 of Set 8 | huesca
# Processing Record 31 of Set 8 | traverse city
# Processing Record 32 of Set 8 | lodja
# Processing Record 33 of Set 8 | broken hill
# Processing Record 34 of Set 8 | ewa beach
# Processing Record 35 of Set 8 | moorhead
# Processing Record 36 of Set 8 | saint anthony
# Processing Record 37 of Set 8 | tautira
# Processing Record 38 of Set 8 | kwekwe
# Processing Record 39 of Set 8 | durres
# Processing Record 40 of Set 8 | kjopsvik
# Processing Record 41 of Set 8 | saint-pierre
# Processing Record 42 of Set 8 | dingle
# Processing Record 43 of Set 8 | prado
# Processing Record 44 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 45 of Set 8 | bageshwar
# Processing Record 46 of Set 8 | khani
# Processing Record 47 of Set 8 | evensk
# Processing Record 48 of Set 8 | kolpashevo
# Processing Record 49 of Set 8 | tarko-sale
# Processing Record 50 of Set 8 | wewak
# Processing Record 1 of Set 9 | belgrade
# Processing Record 2 of Set 9 | saint-augustin
# Processing Record 3 of Set 9 | katherine
# Processing Record 4 of Set 9 | liwale
# Processing Record 5 of Set 9 | jubayl
# City not found. Skipping...
# Processing Record 6 of Set 9 | olafsvik
# Processing Record 7 of Set 9 | rawlins
# Processing Record 8 of Set 9 | natal
# Processing Record 9 of Set 9 | macae
# Processing Record 10 of Set 9 | aklavik
# Processing Record 11 of Set 9 | gurgan
# City not found. Skipping...
# Processing Record 12 of Set 9 | ajdabiya
# Processing Record 13 of Set 9 | nabire
# Processing Record 14 of Set 9 | la cruz
# Processing Record 15 of Set 9 | hovd
# Processing Record 16 of Set 9 | orlik
# Processing Record 17 of Set 9 | sao joao da barra
# Processing Record 18 of Set 9 | okhotsk
# Processing Record 19 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 9 | mechetinskaya
# Processing Record 21 of Set 9 | constitucion
# Processing Record 22 of Set 9 | vila franca do campo
# Processing Record 23 of Set 9 | vila
# Processing Record 24 of Set 9 | lagoa
# Processing Record 25 of Set 9 | esmeraldas
# Processing Record 26 of Set 9 | mobaye
# Processing Record 27 of Set 9 | porto walter
# Processing Record 28 of Set 9 | chojnice
# Processing Record 29 of Set 9 | corn island
# Processing Record 30 of Set 9 | byron bay
# Processing Record 31 of Set 9 | san jose
# Processing Record 32 of Set 9 | mackay
# Processing Record 33 of Set 9 | ayagoz
# Processing Record 34 of Set 9 | spassk
# Processing Record 35 of Set 9 | mountain home
# Processing Record 36 of Set 9 | fairbanks
# Processing Record 37 of Set 9 | katha
# City not found. Skipping...
# Processing Record 38 of Set 9 | teeli
# Processing Record 39 of Set 9 | coquimbo
# Processing Record 40 of Set 9 | andevoranto
# City not found. Skipping...
# Processing Record 41 of Set 9 | obo
# Processing Record 42 of Set 9 | kalaleh
# Processing Record 43 of Set 9 | la ronge
# Processing Record 44 of Set 9 | novska
# Processing Record 45 of Set 9 | panama city
# Processing Record 46 of Set 9 | sereflikochisar
# Processing Record 47 of Set 9 | bobonong
# City not found. Skipping...
# Processing Record 48 of Set 9 | mitu
# Processing Record 49 of Set 9 | nichinan
# Processing Record 50 of Set 9 | damaturu
# Processing Record 1 of Set 10 | sawakin
# Processing Record 2 of Set 10 | chissamba
# Processing Record 3 of Set 10 | baykit
# Processing Record 4 of Set 10 | skibbereen
# Processing Record 5 of Set 10 | pirgos
# Processing Record 6 of Set 10 | dymytrove
# Processing Record 7 of Set 10 | paris
# Processing Record 8 of Set 10 | cairns
# Processing Record 9 of Set 10 | kumasi
# Processing Record 10 of Set 10 | tyristrand
# Processing Record 11 of Set 10 | wanning
# Processing Record 12 of Set 10 | richards bay
# Processing Record 13 of Set 10 | garowe
# Processing Record 14 of Set 10 | mirnyy
# Processing Record 15 of Set 10 | changde
# Processing Record 16 of Set 10 | filadelfia
# Processing Record 17 of Set 10 | skjervoy
# Processing Record 18 of Set 10 | gobabis
# Processing Record 19 of Set 10 | narbonne
# Processing Record 20 of Set 10 | kargasok
# Processing Record 21 of Set 10 | outlook
# Processing Record 22 of Set 10 | sisophon
# Processing Record 23 of Set 10 | ballina
# Processing Record 24 of Set 10 | mercedes
# Processing Record 25 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 26 of Set 10 | mehran
# Processing Record 27 of Set 10 | sapiranga
# Processing Record 28 of Set 10 | shingu
# Processing Record 29 of Set 10 | jodhpur
# Processing Record 30 of Set 10 | kjollefjord
# Processing Record 31 of Set 10 | puerto escondido
# Processing Record 32 of Set 10 | te anau
# Processing Record 33 of Set 10 | ulagan
# Processing Record 34 of Set 10 | dunedin
# Processing Record 35 of Set 10 | lompoc
# Processing Record 36 of Set 10 | lagos
# Processing Record 37 of Set 10 | santa maria
# Processing Record 38 of Set 10 | nhulunbuy
# Processing Record 39 of Set 10 | manzhouli
# Processing Record 40 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 41 of Set 10 | neka
# Processing Record 42 of Set 10 | zhigansk
# Processing Record 43 of Set 10 | puerto madero
# Processing Record 44 of Set 10 | iisalmi
# Processing Record 45 of Set 10 | yerbogachen
# Processing Record 46 of Set 10 | benton harbor
# Processing Record 47 of Set 10 | dzhebariki-khaya
# Processing Record 48 of Set 10 | bria
# Processing Record 49 of Set 10 | kasama
# Processing Record 50 of Set 10 | esperance
# Processing Record 1 of Set 11 | makung
# City not found. Skipping...
# Processing Record 2 of Set 11 | yulara
# Processing Record 3 of Set 11 | tucumcari
# Processing Record 4 of Set 11 | puerto leguizamo
# Processing Record 5 of Set 11 | great bend
# Processing Record 6 of Set 11 | stolin
# Processing Record 7 of Set 11 | inirida
# Processing Record 8 of Set 11 | the valley
# Processing Record 9 of Set 11 | coahuayana
# Processing Record 10 of Set 11 | pisco
# Processing Record 11 of Set 11 | chapada dos guimaraes
# Processing Record 12 of Set 11 | katete
# Processing Record 13 of Set 11 | marv dasht
# City not found. Skipping...
# Processing Record 14 of Set 11 | aanekoski
# Processing Record 15 of Set 11 | paducah
# Processing Record 16 of Set 11 | karaton
# Processing Record 17 of Set 11 | deh rawud
# City not found. Skipping...
# Processing Record 18 of Set 11 | tateyama
# Processing Record 19 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 20 of Set 11 | ikare
# Processing Record 21 of Set 11 | formosa
# Processing Record 22 of Set 11 | wajir
# Processing Record 23 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 24 of Set 11 | ust-nera
# Processing Record 25 of Set 11 | port moresby
# Processing Record 26 of Set 11 | lima
# Processing Record 27 of Set 11 | komsomolskiy
# Processing Record 28 of Set 11 | kamenka
# Processing Record 29 of Set 11 | camocim
# Processing Record 30 of Set 11 | suao
# City not found. Skipping...
# Processing Record 31 of Set 11 | marsh harbour
# Processing Record 32 of Set 11 | beloha
# Processing Record 33 of Set 11 | nouadhibou
# Processing Record 34 of Set 11 | geraldton
# Processing Record 35 of Set 11 | dromolaxia
# Processing Record 36 of Set 11 | eskasem
# City not found. Skipping...
# Processing Record 37 of Set 11 | tura
# Processing Record 38 of Set 11 | krasnoarmeysk
# Processing Record 39 of Set 11 | porto velho
# Processing Record 40 of Set 11 | loudi
# Processing Record 41 of Set 11 | sovetskiy
# Processing Record 42 of Set 11 | hervey bay
# Processing Record 43 of Set 11 | playas
# Processing Record 44 of Set 11 | sokolo
# Processing Record 45 of Set 11 | nsanje
# Processing Record 46 of Set 11 | sapa
# Processing Record 47 of Set 11 | saint-paul
# Processing Record 48 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 49 of Set 11 | whitehorse
# Processing Record 50 of Set 11 | innisfail
# Processing Record 1 of Set 12 | pandan
# Processing Record 2 of Set 12 | mogadishu
# Processing Record 3 of Set 12 | changji
# Processing Record 4 of Set 12 | aasiaat
# Processing Record 5 of Set 12 | nome
# Processing Record 6 of Set 12 | mount pleasant
# Processing Record 7 of Set 12 | susanville
# Processing Record 8 of Set 12 | comodoro rivadavia
# Processing Record 9 of Set 12 | pervomayskiy
# Processing Record 10 of Set 12 | strezhevoy
# Processing Record 11 of Set 12 | omboue
# Processing Record 12 of Set 12 | sabla
# Processing Record 13 of Set 12 | korla
# Processing Record 14 of Set 12 | lucapa
# Processing Record 15 of Set 12 | bairiki
# Processing Record 16 of Set 12 | pangody
# Processing Record 17 of Set 12 | tadine
# Processing Record 18 of Set 12 | igbo ora
# Processing Record 19 of Set 12 | kita
# Processing Record 20 of Set 12 | miraflores
# Processing Record 21 of Set 12 | adoni
# Processing Record 22 of Set 12 | sabinas
# Processing Record 23 of Set 12 | mezen
# Processing Record 24 of Set 12 | ende
# Processing Record 25 of Set 12 | ulety
# Processing Record 26 of Set 12 | manzil jamil
# City not found. Skipping...
# Processing Record 27 of Set 12 | benguela
# Processing Record 28 of Set 12 | jijiga
# Processing Record 29 of Set 12 | rocha
# Processing Record 30 of Set 12 | abapo
# Processing Record 31 of Set 12 | portland
# Processing Record 32 of Set 12 | bayshore gardens
# Processing Record 33 of Set 12 | stromness
# Processing Record 34 of Set 12 | derzhavinsk
# Processing Record 35 of Set 12 | yefira
# City not found. Skipping...
# Processing Record 36 of Set 12 | tilichiki
# Processing Record 37 of Set 12 | santa marta
# Processing Record 38 of Set 12 | ayacucho
# Processing Record 39 of Set 12 | abha
# Processing Record 40 of Set 12 | wuchang
# Processing Record 41 of Set 12 | ampanihy
# Processing Record 42 of Set 12 | waipawa
# Processing Record 43 of Set 12 | miandrivazo
# Processing Record 44 of Set 12 | imbituba
# Processing Record 45 of Set 12 | flin flon
# Processing Record 46 of Set 12 | casa grande
# Processing Record 47 of Set 12 | ornskoldsvik
# Processing Record 48 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 49 of Set 12 | kawalu
# Processing Record 50 of Set 12 | bokhan
# Processing Record 1 of Set 13 | flinders
# Processing Record 2 of Set 13 | patiya
# Processing Record 3 of Set 13 | lakshmipur
# Processing Record 4 of Set 13 | daru
# Processing Record 5 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 13 | tungkang
# City not found. Skipping...
# Processing Record 7 of Set 13 | algemesi
# Processing Record 8 of Set 13 | isabela
# Processing Record 9 of Set 13 | edson
# Processing Record 10 of Set 13 | barranca
# Processing Record 11 of Set 13 | sobolevo
# Processing Record 12 of Set 13 | corvallis
# Processing Record 13 of Set 13 | baherden
# Processing Record 14 of Set 13 | klyuchi
# Processing Record 15 of Set 13 | aguilas
# Processing Record 16 of Set 13 | sinegorye
# Processing Record 17 of Set 13 | lewisporte
# Processing Record 18 of Set 13 | collie
# Processing Record 19 of Set 13 | ouallam
# Processing Record 20 of Set 13 | altay
# Processing Record 21 of Set 13 | namatanai
# Processing Record 22 of Set 13 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 23 of Set 13 | jawhar
# Processing Record 24 of Set 13 | xining
# Processing Record 25 of Set 13 | lichinga
# Processing Record 26 of Set 13 | kupino
# Processing Record 27 of Set 13 | takoradi
# Processing Record 28 of Set 13 | paamiut
# Processing Record 29 of Set 13 | bay city
# Processing Record 30 of Set 13 | isangel
# Processing Record 31 of Set 13 | ambilobe
# Processing Record 32 of Set 13 | letlhakane
# Processing Record 33 of Set 13 | resistencia
# Processing Record 34 of Set 13 | vallenar
# Processing Record 35 of Set 13 | nalhati
# Processing Record 36 of Set 13 | ikeda
# Processing Record 37 of Set 13 | nimes
# Processing Record 38 of Set 13 | vostok
# Processing Record 39 of Set 13 | port shepstone
# Processing Record 40 of Set 13 | cabedelo
# Processing Record 41 of Set 13 | kuching
# Processing Record 42 of Set 13 | isla vista
# Processing Record 43 of Set 13 | gayny
# Processing Record 44 of Set 13 | scarborough
# Processing Record 45 of Set 13 | alappuzha
# Processing Record 46 of Set 13 | california city
# Processing Record 47 of Set 13 | saint-francois
# Processing Record 48 of Set 13 | liberia
# Processing Record 49 of Set 13 | gazimurskiy zavod
# Processing Record 50 of Set 13 | dawei
# Processing Record 1 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 2 of Set 14 | cabinda
# Processing Record 3 of Set 14 | labuhan
# Processing Record 4 of Set 14 | juybar
# Processing Record 5 of Set 14 | yatou
# Processing Record 6 of Set 14 | los chiles
# Processing Record 7 of Set 14 | linfen
# Processing Record 8 of Set 14 | ban nahin
# Processing Record 9 of Set 14 | coihaique
# Processing Record 10 of Set 14 | gushikawa
# Processing Record 11 of Set 14 | tambura
# Processing Record 12 of Set 14 | vizinga
# Processing Record 13 of Set 14 | arzgir
# Processing Record 14 of Set 14 | nemuro
# Processing Record 15 of Set 14 | pahrump
# Processing Record 16 of Set 14 | walvis bay
# Processing Record 17 of Set 14 | hanumangarh
# Processing Record 18 of Set 14 | svetlyy
# Processing Record 19 of Set 14 | rincon
# Processing Record 20 of Set 14 | rantepao
# Processing Record 21 of Set 14 | sabang
# Processing Record 22 of Set 14 | dubenskiy
# City not found. Skipping...
# Processing Record 23 of Set 14 | palmer
# Processing Record 24 of Set 14 | alghero
# Processing Record 25 of Set 14 | havelock
# Processing Record 26 of Set 14 | kainantu
# Processing Record 27 of Set 14 | roma
# Processing Record 28 of Set 14 | big bend
# Processing Record 29 of Set 14 | rosport
# Processing Record 30 of Set 14 | sur
# Processing Record 31 of Set 14 | riyadh
# Processing Record 32 of Set 14 | bukachacha
# Processing Record 33 of Set 14 | amurzet
# Processing Record 34 of Set 14 | lebedinyy
# Processing Record 35 of Set 14 | marfino
# Processing Record 36 of Set 14 | hasaki
# Processing Record 37 of Set 14 | ibra
# Processing Record 38 of Set 14 | naryan-mar
# Processing Record 39 of Set 14 | valparaiso
# Processing Record 40 of Set 14 | horta
# Processing Record 41 of Set 14 | pacific grove
# Processing Record 42 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 43 of Set 14 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 14 | nioro
# Processing Record 45 of Set 14 | porto recanati
# Processing Record 46 of Set 14 | kalmunai
# Processing Record 47 of Set 14 | saint peters
# Processing Record 48 of Set 14 | port lincoln
# Processing Record 49 of Set 14 | debre tabor
# Processing Record 50 of Set 14 | gamba
# Processing Record 1 of Set 15 | vilhena
# Processing Record 2 of Set 15 | caibarien
# Processing Record 3 of Set 15 | margate
# Processing Record 4 of Set 15 | san jose del guaviare
# Processing Record 5 of Set 15 | plettenberg bay
# Processing Record 6 of Set 15 | salamiyah
# Processing Record 7 of Set 15 | benidorm
# Processing Record 8 of Set 15 | bermeo
# Processing Record 9 of Set 15 | vrangel
# Processing Record 10 of Set 15 | longonjo
# Processing Record 11 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 12 of Set 15 | necochea
# Processing Record 13 of Set 15 | winnemucca
# Processing Record 14 of Set 15 | tazovskiy
# Processing Record 15 of Set 15 | buala
# Processing Record 16 of Set 15 | ingham
# Processing Record 17 of Set 15 | puerto parra
# Processing Record 18 of Set 15 | bagdarin
# Processing Record 19 of Set 15 | novikovo
# Processing Record 20 of Set 15 | kandiari
# Processing Record 21 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 15 | kanashevo
# Processing Record 23 of Set 15 | north bend
# Processing Record 24 of Set 15 | vuktyl
# Processing Record 25 of Set 15 | shubarkuduk
# Processing Record 26 of Set 15 | taber
# Processing Record 27 of Set 15 | buritis
# Processing Record 28 of Set 15 | gawler
# Processing Record 29 of Set 15 | asau
# Processing Record 30 of Set 15 | clifton
# Processing Record 31 of Set 15 | spencer
# Processing Record 32 of Set 15 | kiunga
# Processing Record 33 of Set 15 | honiara
# Processing Record 34 of Set 15 | ambon
# Processing Record 35 of Set 15 | aguazul
# Processing Record 36 of Set 15 | seymchan
# Processing Record 37 of Set 15 | celestun
# Processing Record 38 of Set 15 | puerto madryn
# Processing Record 39 of Set 15 | muravlenko
# Processing Record 40 of Set 15 | ixtapa
# Processing Record 41 of Set 15 | shekhupura
# Processing Record 42 of Set 15 | fevralsk
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
weatherpy_data_df = pd.DataFrame(weatherpy_data)

# format & rearrange
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
weatherpy_data_df = weatherpy_data_df[new_column_order]

# %%
weatherpy_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Salalah      OM  17.0151   54.0924     81.16        85         100
# 1     Thompson      CA  55.7435  -97.8558     46.56        25          20
# 2      Astoria      US  46.1879 -123.8313     62.71        65          40
# 3        Bluff      NZ -46.6000  168.3333     50.34        80         100
# 4       Hobart      AU -42.8794  147.3294     44.26        89          75
# 5      Rikitea      PF -23.1203 -134.9692     75.24        74          12
# 6     Klaksvik      FO  62.2266   -6.5890     49.12        87          99
# 7      Ushuaia      AR -54.8000  -68.3000     42.46        65          40
# 8  Yellowknife      CA  62.4560 -114.3525     55.92        41          75
# 9        Vaini      TO -21.2000 -175.2000     69.96        94          75
#
#    Wind Speed Current Description
# 0        7.11     overcast clouds
# 1       11.50          few clouds
# 2        5.75    scattered clouds
# 3       29.48          light rain
# 4       10.36       broken clouds
# 5        6.60          few clouds
# 6       14.72     overcast clouds
# 7       11.50    scattered clouds
# 8        5.75       broken clouds
# 9        4.61       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
weatherpy_data_df.to_csv(output_data_file, index_label = "City_ID")
